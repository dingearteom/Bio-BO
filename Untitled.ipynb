# %%
import os
import sys
sys.path.insert(1, '/home/artem/Desktop/programming/GPyOpt')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import GPyOpt
import deminf_data
import matplotlib.pyplot as plt
plt.style.use('classic')
print(GPyOpt)
# Out:
# <module 'GPyOpt' from '/home/artem/anaconda3/lib/python3.8/site-packages/GPyOpt-1.2.6-py3.8.egg/GPyOpt/__init__.py'>

# %%
objective = deminf_data.Objective.from_name('1_Bot_4_Sim', negate=True, type_of_transform='logarithm')

# %%
bounds = []
for i, (l, r) in enumerate(zip(objective.lower_bound, objective.upper_bound), start=1):
    bounds.append({'name': f'var_{i}', 'type': 'continuous', 'domain': (l, r)})

# %%
def f(x):
    y = []
    for point in x:
        y.append(objective(point))
    return y

# %%
model = GPyOpt.methods.BayesianOptimization(f=f,
                                             domain=bounds,
                                             model_type='GP',
                                             acquisition_type='EI',
                                             normalize_Y=True,
                                             acquisition_weight=2,
                                             model_update_interval=1,
                                             verbosity=True)

# %%
model.run_optimization(20)

# %%
model.plot_acquisition(fixed_values=[None, None, -5.67969664, -1.34564144])

# %%
model.plot_acquisition(fixed_values=[None,-5.39385855,  -5.67969664, -31.34564144])
